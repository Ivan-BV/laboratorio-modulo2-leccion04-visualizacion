# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Visualización
#
# En este laboratorio usaremos el DataFrame de Netflix completo creado en los primeros laboratorios de Pandas.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.
#
# 3. Debes incluir después de cada gráfica la interpretación de las mismas en una celda de markdown.

# %% [markdown]
# #### Ejercicio 1: ¿Cuántos títulos por tipo (Películas vs Series) tenemos?. En esta gráfica deberás:
#
# - Incluir un título.
#
# - Cambiar el nombre de los ejes X e Y.
#
# - Cambiar el color de las barras.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("datos/netflix_merge_left.csv", index_col=0)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA        NaN
# 3  September 24, 2021          2021  TV-MA        NaN
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description                 Title  \
# 0  As her father nears the end of his life, filmm...  Dick Johnson Is Dead
# 1  After crossing paths at a party, a Cape Town t...                   NaN
# 2  To protect his family from a powerful drug lor...                   NaN
# 3  Feuds, flirtations and toilet talk go down amo...                   NaN
# 4  In a city of coaching centers known to train I...                   NaN
#
#          Genre         Premiere  Runtime  IMDB Score Language
# 0  Documentary  October 2, 2020     90.0         7.5  English
# 1          NaN              NaN      NaN         NaN      NaN
# 2          NaN              NaN      NaN         NaN      NaN
# 3          NaN              NaN      NaN         NaN      NaN
# 4          NaN              NaN      NaN         NaN      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9,5))
sns.countplot(x="type",
            data=df,
            palette="crest");
plt.xlabel("Tipo")
plt.ylabel("Cantidad")
plt.title("Cantidad de titulos por tipo")
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3323605000.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="type",
# Text(0.5, 1.0, 'Cantidad de titulos por tipo')

# %% [markdown]
# #### Ejercicio 2: ¿Cuál es la distribución de calificaciones (rating) en los títulos? En esta gráfica deberás:
#
# - Mostrar los resultados ordenados de mayor a menor.
#
# - Rotar las etiquetas del eje X.
#
# - Quitar el nombre del eje X.
#
# - Cambiar el nombre del ehje Y.
#
# - Ponerle título a la gráfica.

# %%
filtro = df["rating"].str.contains(r"-|nr|r|g|ur", case=False, na=False)
df_filtrado = df[filtro]["rating"].value_counts().reset_index()
plt.figure(figsize=(9,5))
sns.barplot(x="rating",
            y="count",
            data=df_filtrado,
            palette="crest")
plt.xticks(rotation=90)
plt.xlabel(None)
plt.ylabel("Cantidad")
plt.title("Distribución de calificaciones");
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3093662995.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="rating",

# %% [markdown]
# #### Ejercicio 3: ¿Cuál es el top 10 de países con más títulos disponibles? Deberás:
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rotar las etiquetas del eje X.

# %%
df_agrupado = df.groupby("country")["title"].count().reset_index().sort_values(by = "title", ascending = False).nlargest(10, "title")

plt.figure(figsize=(11,7))
sns.barplot(x="title",
            y = "country",
            data = df_agrupado,
            palette="crest");

# cambiar el nombre del eje y
plt.ylabel("Países")
plt.xlabel("Títulos")
plt.title('Países con más títulos disponibles')
plt.xticks(rotation = 90);
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3840875947.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="title",

# %% [markdown]
# #### Ejercicio 5: ¿Cuál es la puntuación promedio de las películas según su calificación? Deberás:
#
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rotar las etiquetas del eje X.
#
# - Cambia el tamaño de la gráfica a 15 x 5

# %%
filtro_rating = df["rating"].str.contains(r"-|nr|r|g|ur", case=False, na=False)
filtro_imdb = df["IMDB Score"].notnull()

df_filtrado = df[filtro_rating][filtro_imdb].groupby("rating")[["IMDB Score"]].mean().sort_values("IMDB Score", ascending=False)

plt.figure(figsize=(15,5))
sns.barplot(x="rating",
            y="IMDB Score",
            data=df_filtrado,
            palette="crest");
plt.xlabel("Media de puntuación")
plt.ylabel("Clasificación")
plt.title("Puntuación promedio según su calificación")
plt.xticks(rotation=90)
plt.ylim(6,7)
plt.tight_layout()

# He notado que los valores se encuentran entre 6 y 7 por lo que he cortado el valor y para que sea más representativo
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3266671234.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtrado = df[filtro_rating][filtro_imdb].groupby("rating")[["IMDB Score"]].mean().sort_values("IMDB Score", ascending=False)
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3266671234.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="rating",

# %% [markdown]
# #### Ejercicio 6: ¿Cuál es la relación entre la duración de las películas y su puntuación en IMDb? Deberás:
#
# - Cambiar el tamaño de los puntos.
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.

# %%
df_agrupado = df.groupby("IMDB Score")[["Runtime"]].mean().reset_index()

sns.scatterplot(x = "IMDB Score",
                y = "Runtime",
                data = df_agrupado,
                size = 8);

plt.ylabel("Duración")
plt.xlabel("Puntuación IMDB")
plt.title("Busqueda de tendencia entre Score y runtime")
#No hay relación
# Out:
# Text(0.5, 1.0, 'Busqueda de tendencia entre Score y runtime')

# %% [markdown]
# #### Ejercicio 7: ¿Cómo se distribuye la puntuación en IMDb según los 10 idiomas más usados? Deberás:
#
# - Usa una gráfica que nos muestre la mediana y los cuartiles.
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.

# %%
df_leng_mas_frecuente = df.groupby("Language")["IMDB Score"].mean().nlargest(10).reset_index()
df_leng_mas_frecuente

plt.figure(figsize=(10,6))
sns.barplot(x = "IMDB Score",
            y = "Language",
            data = df_leng_mas_frecuente,
            palette = "crest");

plt.title("Distribución de puntuación IMDB en los 10 idiomas más usados", fontsize = 12)
plt.xlabel("IMDB Score")
plt.ylabel("Language")
plt.xlim(7,9)

plt.show() #print de las gráficas
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\2675111226.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "IMDB Score",

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los 10 directores que tienen las puntuaciones más altas?
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.
#
# - Cambiar el tamaño de la gráfica.

# %%
df_agrupado = df.groupby("director")[["IMDB Score"]].max().reset_index().sort_values("IMDB Score", ascending=False).nlargest(10, "IMDB Score")
df_agrupado
plt.figure(figsize=(15,9))
sns.barplot(x = "director",
            y="IMDB Score",
            data=df_agrupado,
            palette="crest");

plt.xlabel("Director")
plt.ylabel("Puntuación máxima")
plt.title("Los 10 directores con las puntuaciones más altas")
plt.xticks(rotation=90)
plt.ylim(7,10)
plt.tight_layout()

# He hecho igual que en el ejercicio 5. He notado que los valores se encuentran entre 8 y 10 por lo que he cortado el valor y para que sea más representativo. Pero por si acaso he cortado en 7 para evitar perder información
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\260291388.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "director",

# %% [markdown]
# #### Ejercicio 9:  ¿Cuál es la distribución de títulos por tipo y calificación? Soluciona este ejercicio usando subplots. Deberás:
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.

# %%
df_filtrado = df['rating'].value_counts().reset_index()
fig, axes = plt.subplots(1,2, figsize=(10,5))
sns.countplot(x = "type",
              data = df,
              palette = "crest",
              ax = axes[0]
              );

sns.barplot(x = "rating",
            y = "count",
            data = df_filtrado,
            palette = "crest",
            ax = axes[1]
            );

axes[0].set_xlabel("Tipo")
axes[0].set_ylabel("Total")
axes[0].tick_params(axis = "x", labelrotation = 90)
axes[1].set_title("Distribución de títulos por tipo y clasificación")
axes[1].set_xlabel("Clasificación")
axes[1].set_ylabel("Total")
axes[1].tick_params(axis = 'x',labelrotation = 90)

plt.tight_layout()
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\1463026668.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type",
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\1463026668.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "rating",

# %% [markdown]
# #### Ejercicio 10: ¿Cómo se distribuyen los títulos por país para los 6 principales países? Tienes que crear una gráfica para cada país mostrando los resultados en un subplot. Deberás:
# #### Corrección: En el ejercicio 10, tenemos que sacar el numero de pelis y series (el tipo) para los 6 principales paises, mostrando cada pais en un subplot.
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.

# %%
df_agrupado = df.groupby("country").count().nlargest(6, columns="title").reset_index()
df_filtrado = df_agrupado["country"]
lista_paises = list(df_filtrado)

fig, axes = plt.subplots(2,3, figsize=(10,10))
i=0
j=0
bucle = 0
for pais in lista_paises:
    df_paises = df[df["country"]== pais]
    if bucle == 3:
        i=1
        j=0
        print(f"{i}{j}")
    sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
    axes[i][j].set_xlabel(pais)
    axes[i][j].set_ylabel("Número películas y series")
    if bucle <= 2:
        i = 0
        j += 1
    if bucle >= 2:
        i = 1
        j += 1
    bucle +=1
plt.show()
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\218075312.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "type", data = df_paises, palette="crest", ax=axes[i][j])
# 10

# %% [markdown]
# #### Ejercicio 11: ¿Cuál es total de tipos de calificaciones, considerando solo los principales 5 países? Deberás:
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.

# %%
df_agrupado = df.groupby("country")[["rating"]].count().nlargest(5, columns="rating")
plt.figure(figsize=(10,5))
sns.barplot(x="country",
            y="rating",
            data=df_agrupado,
            palette="crest")
plt.title("Total de calificaciones de los 5 principales paises")
plt.xlabel("Cantidad total de tipos de calificaciones")
plt.ylabel("Paises")
plt.xticks(rotation=90);
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\926252452.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="country",

# %% [markdown]
# #### Ejercicio 12: ¿Cómo se distribuyen las 5 primeras calificaciones  a lo largo de los últimos 10 años?
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.
#
# - Elimina el nombre del eje X.

# %%
filtro_rating = df["rating"].str.contains(r"-|nr|r|g|ur", case=False, na=False)

filtro_yr = df["release_year"].between(df["release_year"].max()-10,df["release_year"].max(),inclusive = "both")

df_filtrado = df[filtro_rating & filtro_yr].groupby(["rating","release_year"])[["title"]].count()

plt.figure(figsize=(10,5))
sns.lineplot(x="release_year",
             y="rating",
             data=df_filtrado,
             palette="crest",
             errorbar= None,
             linewidth = 1,
             linestyle = "dashed", 
             marker = "o");
# Out:
# C:\Users\ivigo\AppData\Local\Temp\ipykernel_23504\3344635140.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x="release_year",

# %% [markdown]
# ### BONUS
#
# #### Ejercicio 13: ¿Cómo ha evolucionado la cantidad de títulos añadidos a lo largo de los años diferenciando entre Películas y Series?
#
# - Poner nombre a la ejes.
#
# - Poner título a la gráfica.
#
# - Rota las etiquetas del eje X.
#
# - Elimina el nombre del eje X.
#
# - Añade una *grid* al gráfico.

# %% [markdown]
# #### Ejercicio 14: ¿Cómo se distribuyen los títulos según su calificación (rating)? Utiliza un gráfico de “quesitos” para visualizar la proporción de títulos en cada categoría de calificación.

# %% [markdown]
# #### Ejercicio 15: ¿Cómo se distribuyen los títulos según su calificación (rating) y tipo (Películas vs Series)? Utiliza un gráfico countplot con el parámetro hue para diferenciar entre películas y series en cada calificación.
